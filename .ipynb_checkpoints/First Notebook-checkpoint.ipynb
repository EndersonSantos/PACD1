# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option('display.max_columns', 100)

# %% [markdown]
# #### 1. Cleanning Data What is missing
# - PlayerName
# - Born
# - Height
# - Hand
# - LinkPlayer
# - Tournament
# - Location
# #### 2. Organizar Notebook

# %% [markdown]
# ### Reading Data Frame

# %%
sw = pd.read_json('atpplayers.json', lines=True)

# %%
sw.isna().any()
# Out:
# _id           False
# PlayerName    False
# Born          False
# Height        False
# Hand          False
# LinkPlayer    False
# Tournament    False
# Location      False
# Date          False
# Ground        False
# Prize         False
# GameRound     False
# GameRank      False
# Oponent       False
# WL            False
# Score         False
# dtype: bool

# %% [markdown]
# ### Lenght of Data Frame

# %%
len(sw)
# Out:
# 1308835

# %%
sw.head()
# Out:
#                                     _id      PlayerName              Born  \
# 0  {'$oid': '624ab34913b144c54b3c9aba'}  Novak Djokovic  Belgrade, Serbia
# 1  {'$oid': '624ab34913b144c54b3c9abb'}  Novak Djokovic  Belgrade, Serbia
# 2  {'$oid': '624ab34913b144c54b3c9abc'}  Novak Djokovic  Belgrade, Serbia
# 3  {'$oid': '624ab34913b144c54b3c9abd'}  Novak Djokovic  Belgrade, Serbia
# 4  {'$oid': '624ab34913b144c54b3c9abe'}  Novak Djokovic  Belgrade, Serbia
#
#   Height                               Hand  \
# 0    188  Right-Handed, Two-Handed Backhand
# 1    188  Right-Handed, Two-Handed Backhand
# 2    188  Right-Handed, Two-Handed Backhand
# 3    188  Right-Handed, Two-Handed Backhand
# 4    188  Right-Handed, Two-Handed Backhand
#
#                                           LinkPlayer              Tournament  \
# 0  https://www.atptour.com/en/players/novak-djoko...        Davis Cup Finals
# 1  https://www.atptour.com/en/players/novak-djoko...                   Dubai
# 2  https://www.atptour.com/en/players/novak-djoko...        Nitto ATP Finals
# 3  https://www.atptour.com/en/players/novak-djoko...        Nitto ATP Finals
# 4  https://www.atptour.com/en/players/novak-djoko...  ATP Masters 1000 Paris
#
#         Location                     Date Ground       Prize    GameRound  \
# 0  Madrid, Spain  2021.11.22 - 2021.12.05   Hard              Semi-Finals
# 1  Dubai, U.A.E.  2022.02.21 - 2022.02.26   Hard  $2,794,840  Round of 16
# 2   Turin, Italy  2021.11.15 - 2021.11.21   Hard  $7,250,000  Round Robin
# 3   Turin, Italy  2021.11.15 - 2021.11.21   Hard  $7,250,000  Round Robin
# 4  Paris, France  2021.11.01 - 2021.11.07   Hard  �5,207,405       Finals
#
#   GameRank          Oponent WL     Score
# 0       30      Marin Cilic  W     64 62
# 1       26  Karen Khachanov  W     63 76
# 2       12   Cameron Norrie  W     62 61
# 3        5    Andrey Rublev  W     63 62
# 4        2  Daniil Medvedev  W  46 63 63

# %% [markdown]
# ### Selecting Only Switzerland

# %%
switzerland_sw = sw[sw['Location'].str.contains('Switzerland', case=False)]

# %%
switzerland_sw.head()
# Out:
#                                       _id      PlayerName              Born  \
# 769  {'$oid': '624ab34913b144c54b3c9dbb'}  Novak Djokovic  Belgrade, Serbia
# 770  {'$oid': '624ab34913b144c54b3c9dbc'}  Novak Djokovic  Belgrade, Serbia
# 771  {'$oid': '624ab34913b144c54b3c9dbd'}  Novak Djokovic  Belgrade, Serbia
# 772  {'$oid': '624ab34913b144c54b3c9dbe'}  Novak Djokovic  Belgrade, Serbia
# 858  {'$oid': '624ab34913b144c54b3c9e14'}  Novak Djokovic  Belgrade, Serbia
#
#     Height                               Hand  \
# 769    188  Right-Handed, Two-Handed Backhand
# 770    188  Right-Handed, Two-Handed Backhand
# 771    188  Right-Handed, Two-Handed Backhand
# 772    188  Right-Handed, Two-Handed Backhand
# 858    188  Right-Handed, Two-Handed Backhand
#
#                                             LinkPlayer Tournament  \
# 769  https://www.atptour.com/en/players/novak-djoko...      Basel
# 770  https://www.atptour.com/en/players/novak-djoko...      Basel
# 771  https://www.atptour.com/en/players/novak-djoko...      Basel
# 772  https://www.atptour.com/en/players/novak-djoko...      Basel
# 858  https://www.atptour.com/en/players/novak-djoko...      Basel
#
#                Location                     Date Ground       Prize  \
# 769  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  �1,308,100
# 770  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  �1,308,100
# 771  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  �1,308,100
# 772  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  �1,308,100
# 858  Basel, Switzerland  2010.11.01 - 2010.11.07   Hard  �1,225,000
#
#           GameRound GameRank           Oponent WL       Score
# 769     Semi-Finals       32     Kei Nishikori  L  62 67,  06
# 770  Quarter-Finals       59  Marcos Baghdatis  W    26 62 63
# 771     Round of 16       64      Lukasz Kubot  W       61 62
# 772     Round of 32       47    Xavier Malisse  W    62 46 75
# 858          Finals        2     Roger Federer  L    46 63 16

# %% [markdown]
# ### Fix Id

# %%
switzerland_sw._id = switzerland_sw._id.apply(lambda x: str(x).split(":")[1].split("'")[1].split("'")[0])
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/222526879.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw._id = switzerland_sw._id.apply(lambda x: str(x).split(":")[1].split("'")[1].split("'")[0])

# %% [markdown]
# ### Length with data frame with only switzerland

# %%
len(switzerland_sw)
# Out:
# 14828

# %% [markdown]
# ### Cleanning � and turning Prize into numeric

# %%
switzerland_sw['Prize'] = switzerland_sw['Prize'].replace(regex=[r'�'],value='')
switzerland_sw['Prize'] = switzerland_sw['Prize'].replace(regex=[r'$'],value='')
switzerland_sw['Prize'] = switzerland_sw['Prize'].str.replace('$', '')
switzerland_sw.head(2)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3718355054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Prize'] = switzerland_sw['Prize'].replace(regex=[r'�'],value='')
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3718355054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Prize'] = switzerland_sw['Prize'].replace(regex=[r'$'],value='')
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3718355054.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   switzerland_sw['Prize'] = switzerland_sw['Prize'].str.replace('$', '')
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3718355054.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Prize'] = switzerland_sw['Prize'].str.replace('$', '')
#                           _id      PlayerName              Born Height  \
# 769  624ab34913b144c54b3c9dbb  Novak Djokovic  Belgrade, Serbia    188
# 770  624ab34913b144c54b3c9dbc  Novak Djokovic  Belgrade, Serbia    188
#
#                                   Hand  \
# 769  Right-Handed, Two-Handed Backhand
# 770  Right-Handed, Two-Handed Backhand
#
#                                             LinkPlayer Tournament  \
# 769  https://www.atptour.com/en/players/novak-djoko...      Basel
# 770  https://www.atptour.com/en/players/novak-djoko...      Basel
#
#                Location                     Date Ground    Prize  \
# 769  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  1308100
# 770  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  1308100
#
#           GameRound GameRank           Oponent WL       Score
# 769     Semi-Finals       32     Kei Nishikori  L  62 67,  06
# 770  Quarter-Finals       59  Marcos Baghdatis  W    26 62 63

# %%
switzerland_sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14828 entries, 769 to 1308685
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         14828 non-null  object
#  1   PlayerName  14828 non-null  object
#  2   Born        14828 non-null  object
#  3   Height      14828 non-null  object
#  4   Hand        14828 non-null  object
#  5   LinkPlayer  14828 non-null  object
#  6   Tournament  14828 non-null  object
#  7   Location    14828 non-null  object
#  8   Date        14828 non-null  object
#  9   Ground      14828 non-null  object
#  10  Prize       14828 non-null  object
#  11  GameRound   14828 non-null  object
#  12  GameRank    14828 non-null  object
#  13  Oponent     14828 non-null  object
#  14  WL          14828 non-null  object
#  15  Score       14828 non-null  object
# dtypes: object(16)
# memory usage: 2.4+ MB

# %%
len(switzerland_sw[switzerland_sw['Prize'] == ""])
# Out:
# 295

# %% [markdown]
# #### Cleanning Empty Strings on Prize and replacing by the mean since is only 295 missing

# %%
index_to_fill = switzerland_sw[switzerland_sw['Prize'] == ""].index
mean_prize = np.round(np.mean(switzerland_sw[switzerland_sw['Prize']!=""]['Prize'].astype(float)), 0)
switzerland_sw["Prize"].loc[index_to_fill] = mean_prize
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/4101708354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw["Prize"].loc[index_to_fill] = mean_prize

# %%
len(switzerland_sw[switzerland_sw['Prize'] == ""])
# Out:
# 0

# %%
switzerland_sw['Prize'] = switzerland_sw['Prize'].astype(float)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3601817039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Prize'] = switzerland_sw['Prize'].astype(float)

# %% [markdown]
# ### Counting the number of sets depending on the len on the previous feature created

# %%
len(switzerland_sw[switzerland_sw["Score"] == 'null'])
# Out:
# 148

# %%
switzerland_sw[switzerland_sw["Score"] == 'null'].head(3)
# Out:
#                            _id        PlayerName              Born Height  \
# 3669  624ab34913b144c54b3ca90f  Alexander Zverev  Hamburg, Germany    198
# 5376  624ab34913b144c54b3cafba     Andrey Rublev    Moscow, Russia    188
# 5727  624ab34913b144c54b3cb119       Casper Ruud      Oslo, Norway    183
#
#                                    Hand  \
# 3669  Right-Handed, Two-Handed Backhand
# 5376  Right-Handed, Two-Handed Backhand
# 5727  Right-Handed, Two-Handed Backhand
#
#                                              LinkPlayer Tournament  \
# 3669  https://www.atptour.com/en/players/alexander-z...     Geneva
# 5376  https://www.atptour.com/en/players/andrey-rubl...     Gstaad
# 5727  https://www.atptour.com/en/players/casper-ruud...     Gstaad
#
#                  Location                     Date Ground     Prize  \
# 3669  Geneva, Switzerland  2019.05.20 - 2019.05.25   Clay  $524,340
# 5376  Gstaad, Switzerland  2018.07.23 - 2018.07.29   Clay  $501,345
# 5727  Gstaad, Switzerland  2021.07.19 - 2021.07.25   Clay  $419,470
#
#         GameRound GameRank Oponent WL Score
# 3669  Round of 32              bye     null
# 5376  Round of 32              bye     null
# 5727  Round of 32              bye     null

# %%
indices_to_drop = switzerland_sw[switzerland_sw["Score"] == 'null'].index
switzerland_sw.drop(index=indices_to_drop, axis=0, inplace=True)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3207800736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw.drop(index=indices_to_drop, axis=0, inplace=True)

# %% [markdown]
# ### Creating a new column from score to count the number of sets later on

# %%
switzerland_sw.Score.value_counts()
# Out:
# 63 64            285
# 64 64            270
# 46 46            268
# 36 46            266
# 63 62            237
#                 ...
# 16 61 64           1
# 76,  02 (RET)      1
# 31 (RET)           1
# 63 06 16           1
# 06 63 26           1
# Name: Score, Length: 1776, dtype: int64

# %%
switzerland_sw['Score_1'] = switzerland_sw['Score'].apply(lambda x: str(x).replace(' ', '').replace(',', '').replace('-',''))

switzerland_sw.head(3)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3668371270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Score_1'] = switzerland_sw['Score'].apply(lambda x: str(x).replace(' ', '').replace(',', '').replace('-',''))
#                           _id      PlayerName              Born Height  \
# 769  624ab34913b144c54b3c9dbb  Novak Djokovic  Belgrade, Serbia    188
# 770  624ab34913b144c54b3c9dbc  Novak Djokovic  Belgrade, Serbia    188
# 771  624ab34913b144c54b3c9dbd  Novak Djokovic  Belgrade, Serbia    188
#
#                                   Hand  \
# 769  Right-Handed, Two-Handed Backhand
# 770  Right-Handed, Two-Handed Backhand
# 771  Right-Handed, Two-Handed Backhand
#
#                                             LinkPlayer Tournament  \
# 769  https://www.atptour.com/en/players/novak-djoko...      Basel
# 770  https://www.atptour.com/en/players/novak-djoko...      Basel
# 771  https://www.atptour.com/en/players/novak-djoko...      Basel
#
#                Location                     Date Ground       Prize  \
# 769  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 770  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 771  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
#
#           GameRound GameRank           Oponent WL       Score Score_1
# 769     Semi-Finals       32     Kei Nishikori  L  62 67,  06  626706
# 770  Quarter-Finals       59  Marcos Baghdatis  W    26 62 63  266263
# 771     Round of 16       64      Lukasz Kubot  W       61 62    6162

# %% [markdown]
# Quandoo score é null podemos ver que que o nome do oponente é bye, provavelmente significa que não apareceu, logo nem sequer fazer sentido manter esses casos, vamos fazer o drop desses indices que são apenas 148 casos

# %%
def contar_sets(score_1):
    num_digitos = len(score_1)
    resultado = score_1
    if '(RET)' in score_1:

        ret_pos = score_1.find('(RET)')
        num_digitos = sum(c.isdigit() for c in score_1[:ret_pos])
        
    else:
        num_digitos = sum(c.isdigit() for c in score_1)

    if num_digitos == 10:
        return 5
    elif num_digitos == 8:
        return 4
    elif num_digitos == 6:
        return 3
    elif num_digitos == 4:
        return 2
    elif num_digitos == 2:
        return 1
    elif resultado == '(W/O)':
        return 0
    else:
        return None

switzerland_sw['Numero_sets'] = switzerland_sw['Score_1'].apply(contar_sets)

switzerland_sw.head()
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/897209134.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Numero_sets'] = switzerland_sw['Score_1'].apply(contar_sets)
#                           _id      PlayerName              Born Height  \
# 769  624ab34913b144c54b3c9dbb  Novak Djokovic  Belgrade, Serbia    188
# 770  624ab34913b144c54b3c9dbc  Novak Djokovic  Belgrade, Serbia    188
# 771  624ab34913b144c54b3c9dbd  Novak Djokovic  Belgrade, Serbia    188
# 772  624ab34913b144c54b3c9dbe  Novak Djokovic  Belgrade, Serbia    188
# 858  624ab34913b144c54b3c9e14  Novak Djokovic  Belgrade, Serbia    188
#
#                                   Hand  \
# 769  Right-Handed, Two-Handed Backhand
# 770  Right-Handed, Two-Handed Backhand
# 771  Right-Handed, Two-Handed Backhand
# 772  Right-Handed, Two-Handed Backhand
# 858  Right-Handed, Two-Handed Backhand
#
#                                             LinkPlayer Tournament  \
# 769  https://www.atptour.com/en/players/novak-djoko...      Basel
# 770  https://www.atptour.com/en/players/novak-djoko...      Basel
# 771  https://www.atptour.com/en/players/novak-djoko...      Basel
# 772  https://www.atptour.com/en/players/novak-djoko...      Basel
# 858  https://www.atptour.com/en/players/novak-djoko...      Basel
#
#                Location                     Date Ground       Prize  \
# 769  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 770  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 771  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 772  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 858  Basel, Switzerland  2010.11.01 - 2010.11.07   Hard  $1,225,000
#
#           GameRound GameRank           Oponent WL       Score Score_1  \
# 769     Semi-Finals       32     Kei Nishikori  L  62 67,  06  626706
# 770  Quarter-Finals       59  Marcos Baghdatis  W    26 62 63  266263
# 771     Round of 16       64      Lukasz Kubot  W       61 62    6162
# 772     Round of 32       47    Xavier Malisse  W    62 46 75  624675
# 858          Finals        2     Roger Federer  L    46 63 16  466316
#
#      Numero_sets
# 769          3.0
# 770          3.0
# 771          2.0
# 772          3.0
# 858          3.0

# %% [markdown]
# ### Checking the number of rows of the new feature is na

# %%
switzerland_sw['Numero_sets'].isna().sum()
# Out:
# 10

# %% [markdown]
# ### Dropping rows

# %%
switzerland_sw.dropna(subset=['Numero_sets'], inplace=True, axis=0)
switzerland_sw['Numero_sets'].isna().sum()
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/2258402279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw.dropna(subset=['Numero_sets'], inplace=True, axis=0)
# 0

# %% [markdown]
# ### Converting number of setting to integer

# %%
switzerland_sw['Numero_sets'] = switzerland_sw['Numero_sets'].astype(int)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/2617070812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw['Numero_sets'] = switzerland_sw['Numero_sets'].astype(int)

# %%
(switzerland_sw['Score'].str.contains('(RET)').sum() / len(switzerland_sw)) *100
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3648962039.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   (switzerland_sw['Score'].str.contains('(RET)').sum() / len(switzerland_sw)) *100
# 2.426721199727335

# %%
switzerland_sw[switzerland_sw['Score'].str.contains('(RET)')].head(3)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/641300440.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   switzerland_sw[switzerland_sw['Score'].str.contains('(RET)')].head(3)
#                             _id             PlayerName  \
# 9991   624ab34913b144c54b3cc1c1  Roberto Bautista Agut
# 10054  624ab34913b144c54b3cc200  Roberto Bautista Agut
# 14133  624ab34913b144c54b3cd1ef            Marin Cilic
#
#                                  Born Height  \
# 9991     Castellon de la Plana, Spain    183
# 10054    Castellon de la Plana, Spain    183
# 14133  Medjugorje, Bosnia-Herzegovina    198
#
#                                     Hand  \
# 9991   Right-Handed, Two-Handed Backhand
# 10054  Right-Handed, Two-Handed Backhand
# 14133  Right-Handed, Two-Handed Backhand
#
#                                               LinkPlayer Tournament  \
# 9991   https://www.atptour.com/en/players/roberto-bau...     Gstaad
# 10054  https://www.atptour.com/en/players/roberto-bau...     Gstaad
# 14133  https://www.atptour.com/en/players/marin-cilic...      Basel
#
#                   Location                     Date Ground       Prize  \
# 9991   Gstaad, Switzerland  2013.07.22 - 2013.07.28   Clay    $410,200
# 10054  Gstaad, Switzerland  2012.07.16 - 2012.07.22   Clay    $358,425
# 14133   Basel, Switzerland  2017.10.23 - 2017.10.29   Hard  $1,837,425
#
#                   GameRound GameRank         Oponent WL          Score  \
# 9991            Round of 16       54  Victor Hanescu  L  67,  23 (RET)
# 10054  2nd Round Qualifying      245  Martin Fischer  L    16 01 (RET)
# 14133           Round of 32       68   Florian Mayer  W       63 (RET)
#
#          Score_1  Numero_sets
# 9991   6723(RET)            2
# 10054  1601(RET)            2
# 14133    63(RET)            1

# %% [markdown]
# ### Creating date columns and calculating the lenght of the tournament in days

# %%
switzerland_sw[~switzerland_sw['Date'].str.contains('-', case=False)].head()
# Out:
#                               _id     PlayerName                 Born Height  \
# 1029287  624ab423f522444cb238cc78     John James  Adelaide, Australia    183
# 1029288  624ab423f522444cb238cc79     John James  Adelaide, Australia    183
# 1111582  624ab430bfd14c910b86198f  Stefan Edberg    Vastervik, Sweden    188
# 1111583  624ab430bfd14c910b861990  Stefan Edberg    Vastervik, Sweden    188
# 1111595  624ab430bfd14c910b86199c  Stefan Edberg    Vastervik, Sweden    188
#
#                                    Hand  \
# 1029287  Right-Handed, Unknown Backhand
# 1029288  Right-Handed, Unknown Backhand
# 1111582  Right-Handed, Unknown Backhand
# 1111583  Right-Handed, Unknown Backhand
# 1111595  Right-Handed, Unknown Backhand
#
#                                                 LinkPlayer Tournament  \
# 1029287  https://www.atptour.com/en/players/john-james/...     Geneva
# 1029288  https://www.atptour.com/en/players/john-james/...     Geneva
# 1111582  https://www.atptour.com/en/players/stefan-edbe...      Basel
# 1111583  https://www.atptour.com/en/players/stefan-edbe...      Basel
# 1111595  https://www.atptour.com/en/players/stefan-edbe...     Geneva
#
#                     Location        Date Ground     Prize    GameRound  \
# 1029287  Geneva, Switzerland  1980.09.22   Clay   $75,000  Round of 32
# 1029288  Geneva, Switzerland  1980.09.22   Clay   $75,000  Round of 16
# 1111582   Basel, Switzerland  1983.10.10   Hard  $100,000  Round of 16
# 1111583   Basel, Switzerland  1983.10.10   Hard  $100,000  Round of 32
# 1111595  Geneva, Switzerland  1982.09.20   Clay   $75,000  Round of 32
#
#         GameRank           Oponent WL     Score Score_1  Numero_sets
# 1029287        -   Greg Whitecross  W     63 62    6362            2
# 1029288       25    Balazs Taroczy  L     26 26    2626            2
# 1111582       27      Wojtek Fibak  L     67 36    6736            2
# 1111583        -    Erick Iskersky  W     63 61    6361            2
# 1111595        -  Jairo Velasco Sr  L  63 26 06  632606            3

# %%
len(switzerland_sw[~switzerland_sw['Date'].str.contains('-', case=False)])/len(switzerland_sw) *100
# Out:
# 1.4178595773687799

# %% [markdown]
# Podemos ver que os casos em que não temos a data do termino da partida são de torneis datados dos anos oitento que já são dados ultrapassados e que correspondem a apenas 1.4% dos dados

# %%
indices_to_drop = switzerland_sw[~switzerland_sw['Date'].str.contains('-', case=False)].index

switzerland_sw.drop(index=indices_to_drop, axis=0, inplace=True)
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/1991746986.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw.drop(index=indices_to_drop, axis=0, inplace=True)

# %%
switzerland_sw["start_date"] = switzerland_sw["Date"].apply(lambda x: x.split("-")[0])
switzerland_sw["end_date"] = switzerland_sw["Date"].apply(lambda x: x.split("-")[1])
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/407940070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw["start_date"] = switzerland_sw["Date"].apply(lambda x: x.split("-")[0])
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/407940070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw["end_date"] = switzerland_sw["Date"].apply(lambda x: x.split("-")[1])

# %%
switzerland_sw["start_date"] = pd.to_datetime(switzerland_sw["start_date"])
switzerland_sw["end_date"] = pd.to_datetime(switzerland_sw["end_date"])
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/68302794.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw["start_date"] = pd.to_datetime(switzerland_sw["start_date"])
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/68302794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw["end_date"] = pd.to_datetime(switzerland_sw["end_date"])

# %%
switzerland_sw["tornament_days"] = (switzerland_sw["end_date"] - switzerland_sw["start_date"]).dt.days
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/4038897034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw["tornament_days"] = (switzerland_sw["end_date"] - switzerland_sw["start_date"]).dt.days

# %%
switzerland_sw.sort_values("WL").head(3)
# Out:
#                              _id      PlayerName                      Born  \
# 769     624ab34913b144c54b3c9dbb  Novak Djokovic          Belgrade, Serbia
# 774252  624ab40902b187847f6c8774    George Bastl  Ollon, Vaud, Switzerland
# 774255  624ab40902b187847f6c8777    George Bastl  Ollon, Vaud, Switzerland
#
#        Height                               Hand  \
# 769       188  Right-Handed, Two-Handed Backhand
# 774252    183     Right-Handed, Unknown Backhand
# 774255    183     Right-Handed, Unknown Backhand
#
#                                                LinkPlayer Tournament  \
# 769     https://www.atptour.com/en/players/novak-djoko...      Basel
# 774252  https://www.atptour.com/en/players/george-bast...     Geneva
# 774255  https://www.atptour.com/en/players/george-bast...     Gstaad
#
#                    Location                     Date Ground  ...  \
# 769      Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...
# 774252  Geneva, Switzerland  2011.11.07 - 2011.11.13   Hard  ...
# 774255  Gstaad, Switzerland  2011.07.25 - 2011.07.31   Clay  ...
#
#                    GameRound GameRank        Oponent WL       Score Score_1  \
# 769              Semi-Finals       32  Kei Nishikori  L  62 67,  06  626706
# 774252  1st Round Qualifying      520  Adrien Bossel  L       57 46    5746
# 774255  2nd Round Qualifying      248   Peter Luczak  L       26 36    2636
#
#        Numero_sets  start_date   end_date tornament_days
# 769              3  2011-10-31 2011-11-06              6
# 774252           2  2011-11-07 2011-11-13              6
# 774255           2  2011-07-25 2011-07-31              6
#
# [3 rows x 21 columns]

# %%
switzerland_sw.columns
# Out:
# Index(['_id', 'PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer',
#        'Tournament', 'Location', 'Date', 'Ground', 'Prize', 'GameRound',
#        'GameRank', 'Oponent', 'WL', 'Score', 'Score_1', 'Numero_sets',
#        'start_date', 'end_date', 'tornament_days'],
#       dtype='object')

# %%
switzerland_sw.start_date.min()
# Out:
# Timestamp('1971-05-14 00:00:00')

# %%
switzerland_sw.start_date.max()
# Out:
# Timestamp('2022-03-21 00:00:00')

# %% [markdown]
# ### Extract the city

# %%
switzerland_sw["Location"].value_counts()
# Out:
# Geneva, Switzerland                 2897
# Gstaad, Switzerland                 2602
# Basel, Switzerland                  2533
# Switzerland                         2384
# Lugano, Switzerland                  965
# Bossonnens, Switzerland              281
# Biel, Switzerland                    278
# Trimbach, Switzerland                239
# Chiasso, Switzerland                 238
# Oberentfelden, Switzerland           236
# Sion, Switzerland                    230
# Nyon, Switzerland                    164
# Klosters, Switzerland                123
# Wilen, Switzerland                   122
# Neuchatel, Switzerland               121
# Caslano, Switzerland                 120
# Bellevue, Switzerland                118
# Collonge-Bellerive, Switzerland      117
# Schlieren, Switzerland               114
# Rumikon, Switzerland                  95
# Taverne, Switzerland                  62
# Leuggern, Switzerland                 62
# Muttenz, Switzerland                  59
# Lausanne, Switzerland                 58
# Horgen, Switzerland                   57
# Sierre, Switzerland                   57
# Luasanne, Switzerland                 51
# Crans Montana, Switzerland            35
# Geneva, Switzerland, Switzerland      16
# Zurich, Switzerland                    8
# Prilly, Switzerland                    8
# Fribourg, Switzerland                  8
# Reinach, Switzerland                   4
# Name: Location, dtype: int64

# %% [markdown]
# - Select after a year, like old data might be outdated
# - Create id to unique matches

# %%
z = switzerland_sw["start_date"]
plt.figure(figsize=(14,6))
sns.histplot(z)
plt.title("Distribution of ad events", size=30)
plt.ylabel("Frequency", size=20)
plt.xlabel("Dates", size=20);

# %%
switzerland_sw = switzerland_sw[switzerland_sw["start_date"].dt.year >2000]

# %%
z = switzerland_sw["start_date"]
plt.figure(figsize=(14,6))
sns.histplot(z)
plt.title("Distribution of ad events", size=30)
plt.ylabel("Frequency", size=20)
plt.xlabel("Dates", size=20);

# %% [markdown]
# ### Changing the data frame

# %%
switzerland_sw.isna().any()
# Out:
# _id               False
# PlayerName        False
# Born              False
# Height            False
# Hand              False
# LinkPlayer        False
# Tournament        False
# Location          False
# Date              False
# Ground            False
# Prize             False
# GameRound         False
# GameRank          False
# Oponent           False
# WL                False
# Score             False
# Score_1           False
# Numero_sets       False
# start_date        False
# end_date          False
# tornament_days    False
# dtype: bool

# %%
switzerland_sw.columns
# Out:
# Index(['_id', 'PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer',
#        'Tournament', 'Location', 'Date', 'Ground', 'Prize', 'GameRound',
#        'GameRank', 'Oponent', 'WL', 'Score', 'Score_1', 'Numero_sets',
#        'start_date', 'end_date', 'tornament_days'],
#       dtype='object')

# %% [markdown]
# ### Putting in the same row the two players from the same game

# %%
switzerland_sw.head(2)
# Out:
#                           _id      PlayerName              Born Height  \
# 769  624ab34913b144c54b3c9dbb  Novak Djokovic  Belgrade, Serbia    188
# 770  624ab34913b144c54b3c9dbc  Novak Djokovic  Belgrade, Serbia    188
#
#                                   Hand  \
# 769  Right-Handed, Two-Handed Backhand
# 770  Right-Handed, Two-Handed Backhand
#
#                                             LinkPlayer Tournament  \
# 769  https://www.atptour.com/en/players/novak-djoko...      Basel
# 770  https://www.atptour.com/en/players/novak-djoko...      Basel
#
#                Location                     Date Ground  ...       GameRound  \
# 769  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...     Semi-Finals
# 770  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...  Quarter-Finals
#
#     GameRank           Oponent WL       Score Score_1 Numero_sets  start_date  \
# 769       32     Kei Nishikori  L  62 67,  06  626706           3  2011-10-31
# 770       59  Marcos Baghdatis  W    26 62 63  266263           3  2011-10-31
#
#       end_date tornament_days
# 769 2011-11-06              6
# 770 2011-11-06              6
#
# [2 rows x 21 columns]

# %%
switzerland_sw_winner = switzerland_sw[switzerland_sw['WL'] == 'W']
switzerland_sw_losser = switzerland_sw[switzerland_sw['WL'] == 'L']

# %%
switzerland_sw_winner['GameId'] = switzerland_sw_winner['Tournament'] + '_' + switzerland_sw_winner['Location'] + '_' + switzerland_sw_winner['Ground'] + '_' + \
               switzerland_sw_winner['Prize'].astype(str) + '_' + switzerland_sw_winner['GameRound'] + '_' + switzerland_sw_winner['Numero_sets'].astype(str) + \
               '_' + switzerland_sw_winner['tornament_days'].astype(str) + '_' + switzerland_sw_winner['PlayerName']
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/306243031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw_winner['GameId'] = switzerland_sw_winner['Tournament'] + '_' + switzerland_sw_winner['Location'] + '_' + switzerland_sw_winner['Ground'] + '_' + \

# %%
switzerland_sw_losser['GameId'] = switzerland_sw_losser['Tournament'] + '_' + switzerland_sw_losser['Location'] + '_' + switzerland_sw_losser['Ground'] + '_' + \
               switzerland_sw_losser['Prize'].astype(str) + '_' + switzerland_sw_losser['GameRound'] + '_' + switzerland_sw_losser['Numero_sets'].astype(str) + \
               '_' + switzerland_sw_losser['tornament_days'].astype(str) + '_' + switzerland_sw_losser['Oponent']
# Out:
# /var/folders/by/h2v0ff9j4mvgbk5y8d7h456r0000gq/T/ipykernel_9065/3755257034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   switzerland_sw_losser['GameId'] = switzerland_sw_losser['Tournament'] + '_' + switzerland_sw_losser['Location'] + '_' + switzerland_sw_losser['Ground'] + '_' + \

# %%
switzerland_sw.columns
# Out:
# Index(['_id', 'PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer',
#        'Tournament', 'Location', 'Date', 'Ground', 'Prize', 'GameRound',
#        'GameRank', 'Oponent', 'WL', 'Score', 'Score_1', 'Numero_sets',
#        'start_date', 'end_date', 'tornament_days'],
#       dtype='object')

# %%
player_1 = ['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer','Tournament', 'Location', 'Date', 'Ground', 'Prize', 'GameRound','GameRank','Score', 'Score_1', 'Numero_sets',
       'start_date', 'end_date', 'tornament_days','GameId']
player_2 = ['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer','GameRank','GameId']
switzerland_f = pd.merge(switzerland_sw_winner[player_1], switzerland_sw_losser[player_2], on='GameId', how='inner')

# %%
switzerland_f
# Out:
#                          PlayerName_x              Born_x Height_x  \
# 0                      Novak Djokovic    Belgrade, Serbia      188
# 1                      Novak Djokovic    Belgrade, Serbia      188
# 2                      Novak Djokovic    Belgrade, Serbia      188
# 3                      Novak Djokovic    Belgrade, Serbia      188
# 4                      Novak Djokovic    Belgrade, Serbia      188
# ...                               ...                 ...      ...
# 5556  Juan Manuel Benitez Chavarriaga  Medellin, Colombia       NA
# 5557                   Marvin Moeller    Hamburg, Germany      178
# 5558                   Marvin Moeller    Hamburg, Germany      178
# 5559                   Maxence Beauge       Marzy, France      183
# 5560                 Nicolas Parizzia                           NA
#
#                                  Hand_x  \
# 0     Right-Handed, Two-Handed Backhand
# 1     Right-Handed, Two-Handed Backhand
# 2     Right-Handed, Two-Handed Backhand
# 3     Right-Handed, Two-Handed Backhand
# 4     Right-Handed, Two-Handed Backhand
# ...                                 ...
# 5556  Right-Handed, Two-Handed Backhand
# 5557  Right-Handed, Two-Handed Backhand
# 5558  Right-Handed, Two-Handed Backhand
# 5559  Right-Handed, Two-Handed Backhand
# 5560                               null
#
#                                            LinkPlayer_x      Tournament  \
# 0     https://www.atptour.com/en/players/novak-djoko...           Basel
# 1     https://www.atptour.com/en/players/novak-djoko...           Basel
# 2     https://www.atptour.com/en/players/novak-djoko...           Basel
# 3     https://www.atptour.com/en/players/novak-djoko...           Basel
# 4     https://www.atptour.com/en/players/novak-djoko...           Basel
# ...                                                 ...             ...
# 5556  https://www.atptour.com/en/players/juan-manuel...  Switzerland F3
# 5557  https://www.atptour.com/en/players/marvin-moel...    M25 Trimbach
# 5558  https://www.atptour.com/en/players/marvin-moel...  Switzerland F5
# 5559  https://www.atptour.com/en/players/maxence-bea...  Switzerland F3
# 5560  https://www.atptour.com/en/players/nicolas-par...     M25 Caslano
#
#                              Location                     Date  Ground  \
# 0                  Basel, Switzerland  2011.10.31 - 2011.11.06    Hard
# 1                  Basel, Switzerland  2011.10.31 - 2011.11.06    Hard
# 2                  Basel, Switzerland  2010.11.01 - 2010.11.07    Hard
# 3                  Basel, Switzerland  2010.11.01 - 2010.11.07    Hard
# 4                  Basel, Switzerland  2010.11.01 - 2010.11.07    Hard
# ...                               ...                      ...     ...
# 5556  Collonge-Bellerive, Switzerland  2017.08.14 - 2017.08.20    Clay
# 5557            Trimbach, Switzerland  2021.03.08 - 2021.03.14  Carpet
# 5558                Sion, Switzerland  2017.08.28 - 2017.09.03    Clay
# 5559  Collonge-Bellerive, Switzerland  2017.08.14 - 2017.08.20    Clay
# 5560             Caslano, Switzerland  2021.08.23 - 2021.08.29    Clay
#
#            Prize       GameRound GameRank_x       Score Score_1  Numero_sets  \
# 0     $1,308,100     Round of 16         64       61 62    6162            2
# 1     $1,308,100     Round of 32         47    62 46 75  624675            3
# 2     $1,225,000     Semi-Finals         32     76,  64    7664            2
# 3     $1,225,000  Quarter-Finals         66       62 63    6263            2
# 4     $1,225,000     Round of 32         26       64 62    6462            2
# ...          ...             ...        ...         ...     ...          ...
# 5556     $15,000     Round of 16       1011       63 63    6363            2
# 5557     $25,000     Round of 32       1298  61 67,  62  616762            3
# 5558     $15,000     Round of 32        545  61 67,  63  616763            3
# 5559     $15,000     Round of 32        941       61 76    6176            2
# 5560     $25,000     Round of 32       2048    26 62 64  266264            3
#
#      start_date   end_date  tornament_days  \
# 0    2011-10-31 2011-11-06               6
# 1    2011-10-31 2011-11-06               6
# 2    2010-11-01 2010-11-07               6
# 3    2010-11-01 2010-11-07               6
# 4    2010-11-01 2010-11-07               6
# ...         ...        ...             ...
# 5556 2017-08-14 2017-08-20               6
# 5557 2021-03-08 2021-03-14               6
# 5558 2017-08-28 2017-09-03               6
# 5559 2017-08-14 2017-08-20               6
# 5560 2021-08-23 2021-08-29               6
#
#                                                  GameId      PlayerName_y  \
# 0     Basel_Basel, Switzerland_Hard_$1,308,100_Round...      Lukasz Kubot
# 1     Basel_Basel, Switzerland_Hard_$1,308,100_Round...    Xavier Malisse
# 2     Basel_Basel, Switzerland_Hard_$1,225,000_Semi-...    Viktor Troicki
# 3     Basel_Basel, Switzerland_Hard_$1,225,000_Quart...       Robin Haase
# 4     Basel_Basel, Switzerland_Hard_$1,225,000_Round...    Ernests Gulbis
# ...                                                 ...               ...
# 5556  Switzerland F3_Collonge-Bellerive, Switzerland...       Loic Perret
# 5557  M25 Trimbach_Trimbach, Switzerland_Carpet_$25,...  Patrik Hartmeier
# 5558  Switzerland F5_Sion, Switzerland_Clay_$15,000_...       Pascal Meis
# 5559  Switzerland F3_Collonge-Bellerive, Switzerland...     Issei Okamura
# 5560  M25 Caslano_Caslano, Switzerland_Clay_$25,000_...  Gian Luca Tanner
#
#                           Born_y Height_y                             Hand_y  \
# 0            Boleslawiec, Poland      191  Right-Handed, Two-Handed Backhand
# 1              Kortrijk, Belgium      185  Right-Handed, Two-Handed Backhand
# 2               Belgrade, Serbia      193  Right-Handed, Two-Handed Backhand
# 3     The Hague, The Netherlands      191  Right-Handed, Two-Handed Backhand
# 4                   Riga, Latvia      191  Right-Handed, Two-Handed Backhand
# ...                          ...      ...                                ...
# 5556                      Noumea      188  Right-Handed, One-Handed Backhand
# 5557                                   NA                               null
# 5558                  Traunstein      180   Left-Handed, One-Handed Backhand
# 5559                     Okayama      170  Right-Handed, Two-Handed Backhand
# 5560                        Chur      191     Right-Handed, Unknown Backhand
#
#                                            LinkPlayer_y GameRank_y
# 0     https://www.atptour.com/en/players/lukasz-kubo...          1
# 1     https://www.atptour.com/en/players/xavier-mali...          1
# 2     https://www.atptour.com/en/players/viktor-troi...          3
# 3     https://www.atptour.com/en/players/robin-haase...          3
# 4     https://www.atptour.com/en/players/ernests-gul...          3
# ...                                                 ...        ...
# 5556  https://www.atptour.com/en/players/loic-perret...        646
# 5557  https://www.atptour.com/en/players/patrik-hart...        614
# 5558  https://www.atptour.com/en/players/pascal-meis...       1128
# 5559  https://www.atptour.com/en/players/issei-okamu...       1325
# 5560  https://www.atptour.com/en/players/gian-luca-t...       1672
#
# [5561 rows x 25 columns]

# %%
len(switzerland_sw)
# Out:
# 10505

# %%
len(switzerland_sw)/2
# Out:
# 5252.5

# %%
pd.set_option('display.max_columns', 100)

# %%
Tournament
Location
Ground
Prize
GameRound
Numero_sets
tornament_days
Player / Oponent

# %%
len(switzerland_sw_losser)
# Out:
# 5190

# %%
len(switzerland_sw_winner)
# Out:
# 5315

# %%
switzerland_sw_winner.head()
# Out:
#                           _id      PlayerName              Born Height  \
# 770  624ab34913b144c54b3c9dbc  Novak Djokovic  Belgrade, Serbia    188
# 771  624ab34913b144c54b3c9dbd  Novak Djokovic  Belgrade, Serbia    188
# 772  624ab34913b144c54b3c9dbe  Novak Djokovic  Belgrade, Serbia    188
# 859  624ab34913b144c54b3c9e15  Novak Djokovic  Belgrade, Serbia    188
# 860  624ab34913b144c54b3c9e16  Novak Djokovic  Belgrade, Serbia    188
#
#                                   Hand  \
# 770  Right-Handed, Two-Handed Backhand
# 771  Right-Handed, Two-Handed Backhand
# 772  Right-Handed, Two-Handed Backhand
# 859  Right-Handed, Two-Handed Backhand
# 860  Right-Handed, Two-Handed Backhand
#
#                                             LinkPlayer Tournament  \
# 770  https://www.atptour.com/en/players/novak-djoko...      Basel
# 771  https://www.atptour.com/en/players/novak-djoko...      Basel
# 772  https://www.atptour.com/en/players/novak-djoko...      Basel
# 859  https://www.atptour.com/en/players/novak-djoko...      Basel
# 860  https://www.atptour.com/en/players/novak-djoko...      Basel
#
#                Location                     Date Ground       Prize  \
# 770  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 771  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 772  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  $1,308,100
# 859  Basel, Switzerland  2010.11.01 - 2010.11.07   Hard  $1,225,000
# 860  Basel, Switzerland  2010.11.01 - 2010.11.07   Hard  $1,225,000
#
#           GameRound GameRank           Oponent WL     Score Score_1  \
# 770  Quarter-Finals       59  Marcos Baghdatis  W  26 62 63  266263
# 771     Round of 16       64      Lukasz Kubot  W     61 62    6162
# 772     Round of 32       47    Xavier Malisse  W  62 46 75  624675
# 859     Semi-Finals       32    Viktor Troicki  W   76,  64    7664
# 860  Quarter-Finals       66       Robin Haase  W     62 63    6263
#
#      Numero_sets start_date   end_date  tornament_days
# 770            3 2011-10-31 2011-11-06               6
# 771            2 2011-10-31 2011-11-06               6
# 772            3 2011-10-31 2011-11-06               6
# 859            2 2010-11-01 2010-11-07               6
# 860            2 2010-11-01 2010-11-07               6

# %%
switzerland_sw_losser.head()
# Out:
#                            _id       PlayerName              Born Height  \
# 769   624ab34913b144c54b3c9dbb   Novak Djokovic  Belgrade, Serbia    188
# 858   624ab34913b144c54b3c9e14   Novak Djokovic  Belgrade, Serbia    188
# 1244  624ab34913b144c54b3c9f96   Novak Djokovic  Belgrade, Serbia    188
# 1633  624ab34913b144c54b3ca11b  Daniil Medvedev    Moscow, Russia    198
# 1856  624ab34913b144c54b3ca1fa  Daniil Medvedev    Moscow, Russia    198
#
#                                    Hand  \
# 769   Right-Handed, Two-Handed Backhand
# 858   Right-Handed, Two-Handed Backhand
# 1244  Right-Handed, Two-Handed Backhand
# 1633  Right-Handed, Two-Handed Backhand
# 1856  Right-Handed, Two-Handed Backhand
#
#                                              LinkPlayer        Tournament  \
# 769   https://www.atptour.com/en/players/novak-djoko...             Basel
# 858   https://www.atptour.com/en/players/novak-djoko...             Basel
# 1244  https://www.atptour.com/en/players/novak-djoko...  SUI v. SCG WG PO
# 1633  https://www.atptour.com/en/players/daniil-medv...             Basel
# 1856  https://www.atptour.com/en/players/daniil-medv...    Switzerland F1
#
#                         Location                     Date  Ground  ...  \
# 769           Basel, Switzerland  2011.10.31 - 2011.11.06    Hard  ...
# 858           Basel, Switzerland  2010.11.01 - 2010.11.07    Hard  ...
# 1244                 Switzerland  2006.09.18 - 2006.09.24    Hard  ...
# 1633          Basel, Switzerland  2018.10.22 - 2018.10.28    Hard  ...
# 1856  Oberentfelden, Switzerland  2016.02.08 - 2016.02.14  Carpet  ...
#
#            GameRound GameRank            Oponent WL       Score Score_1  \
# 769      Semi-Finals       32      Kei Nishikori  L  62 67,  06  626706
# 858           Finals        2      Roger Federer  L    46 63 16  466316
# 1244     Round Robin        1      Roger Federer  L    36 26 36  362636
# 1633     Semi-Finals        3      Roger Federer  L       16 46    1646
# 1856  Quarter-Finals      242  Uladzimir Ignatik  L  76,  46 36  764636
#
#      Numero_sets  start_date   end_date tornament_days
# 769            3  2011-10-31 2011-11-06              6
# 858            3  2010-11-01 2010-11-07              6
# 1244           3  2006-09-18 2006-09-24              6
# 1633           2  2018-10-22 2018-10-28              6
# 1856           3  2016-02-08 2016-02-14              6
#
# [5 rows x 21 columns]

# %%
switzerland_sw[(switzerland_sw["Date"] == '2011.10.31 - 2011.11.06') & (switzerland_sw["GameRound"] == 'Semi-Finals')]
# Out:
#                              _id      PlayerName                   Born  \
# 769     624ab34913b144c54b3c9dbb  Novak Djokovic       Belgrade, Serbia
# 17134   624ab34913b144c54b3cdda8   Roger Federer     Basel, Switzerland
# 32110   624ab34a13b144c54b3d1828   Kei Nishikori         Shimane, Japan
# 125636  624ab34f936e4d97ffee0bc8   Stan Wawrinka  Lausanne, Switzerland
#
#        Height                               Hand  \
# 769       188  Right-Handed, Two-Handed Backhand
# 17134     185  Right-Handed, One-Handed Backhand
# 32110     178  Right-Handed, Two-Handed Backhand
# 125636    183  Right-Handed, One-Handed Backhand
#
#                                                LinkPlayer Tournament  \
# 769     https://www.atptour.com/en/players/novak-djoko...      Basel
# 17134   https://www.atptour.com/en/players/roger-feder...      Basel
# 32110   https://www.atptour.com/en/players/kei-nishiko...      Basel
# 125636  https://www.atptour.com/en/players/stan-wawrin...      Basel
#
#                   Location                     Date Ground  ...    GameRound  \
# 769     Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...  Semi-Finals
# 17134   Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...  Semi-Finals
# 32110   Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...  Semi-Finals
# 125636  Basel, Switzerland  2011.10.31 - 2011.11.06   Hard  ...  Semi-Finals
#
#        GameRank         Oponent WL       Score Score_1 Numero_sets  \
# 769          32   Kei Nishikori  L  62 67,  06  626706           3
# 17134        19   Stan Wawrinka  W     76,  62    7662           2
# 32110         1  Novak Djokovic  W  26 76,  60  267660           3
# 125636        4   Roger Federer  L     67,  26    6726           2
#
#         start_date   end_date tornament_days
# 769     2011-10-31 2011-11-06              6
# 17134   2011-10-31 2011-11-06              6
# 32110   2011-10-31 2011-11-06              6
# 125636  2011-10-31 2011-11-06              6
#
# [4 rows x 21 columns]
